# %% [markdown]
# <a href="https://colab.research.google.com/github/aditya-524/sta_zc/blob/main/sta_zc%20/01_Data_Source/m1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## STA ZC 01

# %% [markdown]
# ## Question 1: [Macro] Average growth of GDP in 2023.
# ### What is the average growth (in %) of GDP in 2023?
#
# Download the timeseries Real Gross Domestic Product (GDPC1) from FRED (https://fred.stlouisfed.org/series/GDPC1). Calculate year-over-year (YoY) growth rate (that is, divide current value to one 4 quarters ago). Find the average YoY growth in 2023 (average from 4 YoY numbers). Round to 1 digit after the decimal point: e.g. if you get 5.66% growth => you should answer 5.7

# %%
# install main library YFinance
# !pip install yfinance

# %%
# IMPORTS
import numpy as np
import pandas as pd

#Fin Data Sources
import yfinance as yf
import pandas_datareader as pdr

#Data viz
import plotly.graph_objs as go
import plotly.express as px

import time
from datetime import date

# %%
now = date.today()
start = date(year=now.year-3, month=now.month, day=now.day)
gdpc1 = pdr.DataReader("GDPC1", "fred", start=start)

# %%
# gdpc1.head(10)

# %%
yoy_growth = gdpc1.pct_change(4) * 100
yoy_growth = yoy_growth.reset_index()
yoy_growth.head(10)
# Out:
#         DATE     GDPC1
# 0 2021-07-01       NaN
# 1 2021-10-01       NaN
# 2 2022-01-01       NaN
# 3 2022-04-01       NaN
# 4 2022-07-01  1.713213
# 5 2022-10-01  0.651692
# 6 2023-01-01  1.717927
# 7 2023-04-01  2.382468
# 8 2023-07-01  2.926887
# 9 2023-10-01  3.134491

# %%
yoy_growth[yoy_growth['DATE'].dt.year == 2023]['GDPC1'].mean().round(1)
# Out:
# 2.5

# %% [markdown]
# ## Question 2. [Macro] Inverse "Treasury Yield"
# ### Find the min value of (dgs10-dgs2) after since year 2000 (2000-01-01) and write it down as an answer, round to 1 digit after the decimal point.
#
# Download DGS2 and DGS10 interest rates series (https://fred.stlouisfed.org/series/DGS2, https://fred.stlouisfed.org/series/DGS10). Join them together to one dataframe on date (you might need to read about pandas.DataFrame.join()), calculate the difference dgs10-dgs2 daily.
#
# (Additional: think about what does the "inverted yield curve" mean for the market and investors? do you see the same thing in your country/market of interest? Do you think it can be a good predictive feature for the models?)

# %%
q2_start = date(year=2000, month=1, day=1)
dgs2 = pdr.DataReader("DGS2", "fred", start=q2_start)
dgs10 = pdr.DataReader("DGS10", "fred", start=q2_start)

dgs2.head()
# Out:
#             DGS2
# DATE
# 2000-01-03  6.38
# 2000-01-04  6.30
# 2000-01-05  6.38
# 2000-01-06  6.35
# 2000-01-07  6.31

# %%
dgs10.head()
# Out:
#             DGS10
# DATE
# 2000-01-03   6.58
# 2000-01-04   6.49
# 2000-01-05   6.62
# 2000-01-06   6.57
# 2000-01-07   6.52

# %%
n1 = pd.DataFrame(dgs2.join(dgs10)).reset_index()
# n1.head()
n1['DIFF'] = n1['DGS10'] - n1['DGS2']
n1.head()
# Out:
#         DATE  DGS2  DGS10  DIFF
# 0 2000-01-03  6.38   6.58  0.20
# 1 2000-01-04  6.30   6.49  0.19
# 2 2000-01-05  6.38   6.62  0.24
# 3 2000-01-06  6.35   6.57  0.22
# 4 2000-01-07  6.31   6.52  0.21

# %% [markdown]
# Inverted yield curve indicates that short-term interest rates are higher than long-term interest rates. A sign of upcoming recession.

# %% [markdown]
# ## Question 3. [Index] Which Index is better recently?
# ### Compare S&P 500 and IPC Mexico indexes by the 5 year growth and write down the largest value as an answer (%)
#
# Download on Yahoo Finance two daily index prices for S&P 500 (^GSPC, https://finance.yahoo.com/quote/%5EGSPC/) and IPC Mexico (^MXX, https://finance.yahoo.com/quote/%5EMXX/). Compare 5Y growth for both (between 2019-04-09 and 2024-04-09). Select the higher growing index and write down the growth in % (closest integer %). E.g. if ratio end/start was 2.0925 (or growth of 109.25%), you need to write down 109 as your answer.
#
# (Additional: think of other indexes and try to download stats and compare the growth? Do create 10Y and 20Y growth stats. What is an average yearly growth rate (CAGR) for each of the indexes you select?)

# %%
start="2019-04-09"
end="2024-04-09"
sp500 = yf.download("^GSPC", start=start, end=end)
ipc_mexico = yf.download("^MXX", start=start, end=end)

sp500_growth = (sp500["Close"][-1] / sp500["Close"][0] - 1) * 100
ipc_mexico_growth = (ipc_mexico["Close"][-1] / ipc_mexico["Close"][0] - 1) * 100

print("\n S&P", round(sp500_growth))
print("IPC Mexico", round(ipc_mexico_growth))


# Extra question
start_2="2014-04-09"
end_2="2024-04-09"
sp500 = yf.download("^GSPC", start=start_2, end=end_2)
ipc_mexico = yf.download("^MXX", start=start_2, end=end_2)
nifty50 = yf.download("^NSEI", start=start_2, end=end_2)
sensex = yf.download("^BSESN", start=start_2, end=end_2)

print("\n========== 10 Year ================")

sp500_growth = (sp500["Close"][-1] / sp500["Close"][0] - 1) * 100
ipc_mexico_growth = (ipc_mexico["Close"][-1] / ipc_mexico["Close"][0] - 1) * 100
nifty_growth = (nifty50["Close"][-1] / nifty50["Close"][0] - 1) * 100
sensex_growth = (sensex["Close"][-1] / sensex["Close"][0] - 1) * 100
print("\n S&P", round(sp500_growth))
print("IPC Mexico", round(ipc_mexico_growth))
print("Nifty 50", round(nifty_growth))
print("Sensex", round(sensex_growth))


print("\n========== 20 Year ================")

start_3="2004-04-09"
end_3="2004-04-09"
sp500 = yf.download("^GSPC", start=start_3, end=end_3)
ipc_mexico = yf.download("^MXX", start=start_3, end=end_3)
nifty50 = yf.download("^NSEI", start=start_3, end=end_3)
sensex = yf.download("^BSESN", start=start_3, end=end_3)
sp500_growth = (sp500["Close"][-1] / sp500["Close"][0] - 1) * 100
ipc_mexico_growth = (ipc_mexico["Close"][-1] / ipc_mexico["Close"][0] - 1) * 100
nifty_growth = (nifty50["Close"][-1] / nifty50["Close"][0] - 1) * 100
sensex_growth = (sensex["Close"][-1] / sensex["Close"][0] - 1) * 100
print("\n S&P", round(sp500_growth))
print("IPC Mexico", round(ipc_mexico_growth))
print("Nifty 50", round(nifty_growth))
print("Sensex", round(sensex_growth))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['^GSPC']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2004-04-09 -> 2004-04-09)')
# [*********************100%%**********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['^MXX']: YFPricesMissingError('$%ticker%: possibly delisted; No price data found  (1d 2004-04-09 -> 2004-04-09)')
#  S&P 81
# IPC Mexico 28
#
# ========== 10 Year ================
#
#  S&P 178
# ...

# %% [markdown]
# ## Question 4. [Stocks OHLCV] 52-weeks range ratio (2023) for the selected stocks
# ### Find the largest range ratio [=(max-min)/max] of Adj.Close prices in 2023
#
# Download the 2023 daily OHLCV data on Yahoo Finance for top6 stocks on earnings (https://companiesmarketcap.com/most-profitable-companies/): 2222.SR,BRK-B, AAPL, MSFT, GOOG, JPM.
#
# Here is the example data you should see in Pandas for "2222.SR": https://finance.yahoo.com/quote/2222.SR/history
#
# Calculate maximum-minimim "Adj.Close" price for each stock and divide it by the maximum "Adj.Close" value. Round the result to two decimal places (e.g. 0.1575 will be 0.16)
#
# (Additional: why this may be important for your research?)
